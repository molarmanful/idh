# %% [markdown]
# <span style="font-size:large;">
# <div style="text-align: right">IM-UH 1511 <b>Introduction to Digital Humanities</b><br/>
# Student name: <span style="color:blue"><b>Ben Pang</b></span><br/>
# Grade: <span style="color:red"><b></b></span><br/><br/></div>

# %% [markdown]
# ## <span style="color:red">HOMEWORK 1</span>
# # <span style="color:green">Extraction of Names from Text

# %%
import time
start_time = time.time()
import urllib, os, codecs, random, operator, re, string, copy, dateutil.parser, itertools, pickle, datetime, math, pandas as pd, numpy as np, matplotlib.pyplot as plt
from collections import Counter
from string import punctuation, digits
import pathlib
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_lg')
import inflect
import nltk
from nltk import word_tokenize

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.simplefilter('ignore')

# %% [markdown]
# ### Load Data

# %%
# get your working directory
home = str(pathlib.Path.cwd())

# create a path to which the file will be written
text_path = os.path.join(home, 'huckleberry_finn.txt')

# location of the project gutenberg copy of the pride & prejudice text file
text_url = 'http://www.gutenberg.org/files/76/76-0.txt'

urllib.request.urlretrieve(text_url, text_path)

print('Downloaded to:', text_path)
# Out:
# Downloaded to: /home/x/idh/hw1/huckleberry_finn.txt

# %%
f = codecs.open(text_path, "r", encoding="utf-8").readlines()
start, end = 0, 0
for line in f:
    if line.startswith("HUCKLEBERRY FINN"):
        start = f.index(line)
        print(start)
    if line.startswith("End of the Project"):
        end = f.index(line)
        print(end)
# Out:
# 31
# 31
# 11977

# %%
ff=f[start:end]
ff
# Out:
# ['HUCKLEBERRY FINN\r\n',
#  '\r\n',
#  "(Tom Sawyer's Comrade)\r\n",
#  '\r\n',
#  'By Mark Twain\r\n',
#  '\r\n',
#  'Complete\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  'CONTENTS.\r\n',
#  '\r\n',
#  'CHAPTER I. Civilizing Huck.--Miss Watson.--Tom Sawyer Waits.\r\n',
#  '\r\n',
#  "CHAPTER II. The Boys Escape Jim.--Torn Sawyer's Gang.--Deep-laid Plans.\r\n",
#  '\r\n',
#  "CHAPTER III. A Good Going-over.--Grace Triumphant.--“One of Tom Sawyers's\r\n",
#  'Lies”.\r\n',
#  '\r\n',
#  'CHAPTER IV. Huck and the Judge.--Superstition.\r\n',
#  '\r\n',
#  "CHAPTER V. Huck's Father.--The Fond Parent.--Reform.\r\n",
#  '\r\n',
#  'CHAPTER VI. He Went for Judge Thatcher.--Huck Decided to Leave.--Political\r\n',
#  'Economy.--Thrashing Around.\r\n',
#  '\r\n',
#  'CHAPTER VII. Laying for Him.--Locked in the Cabin.--Sinking the\r\n',
#  'Body.--Resting.\r\n',
#  '\r\n',
#  'CHAPTER VIII. Sleeping in the Woods.--Raising the Dead.--Exploring the\r\n',
# ...

# %%
text="\r\n".join(ff)
text
# Out:
# "HUCKLEBERRY FINN\r\n\r\n\r\n\r\n(Tom Sawyer's Comrade)\r\n\r\n\r\n\r\nBy Mark Twain\r\n\r\n\r\n\r\nComplete\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nCONTENTS.\r\n\r\n\r\n\r\nCHAPTER I. Civilizing Huck.--Miss Watson.--Tom Sawyer Waits.\r\n\r\n\r\n\r\nCHAPTER II. The Boys Escape Jim.--Torn Sawyer's Gang.--Deep-laid Plans.\r\n\r\n\r\n\r\nCHAPTER III. A Good Going-over.--Grace Triumphant.--“One of Tom Sawyers's\r\n\r\nLies”.\r\n\r\n\r\n\r\nCHAPTER IV. Huck and the Judge.--Superstition.\r\n\r\n\r\n\r\nCHAPTER V. Huck's Father.--The Fond Parent.--Reform.\r\n\r\n\r\n\r\nCHAPTER VI. He Went for Judge Thatcher.--Huck Decided to Leave.--Political\r\n\r\nEconomy.--Thrashing Around.\r\n\r\n\r\n\r\nCHAPTER VII. Laying for Him.--Locked in the Cabin.--Sinking the\r\n\r\nBody.--Resting.\r\n\r\n\r\n\r\nCHAPTER VIII. Sleeping in the Woods.--Raising the Dead.--Exploring the\r\n\r\nIsland.--Finding Jim.--Jim's Escape.--Signs.--Balum.\r\n\r\n\r\n\r\nCHAPTER IX. The Cave.--The Floating House.\r\n\r\n\r\n\r
# ...

# %%
titlename = "Mark Twain's Adventures of Huckleberry Finn"

words = word_tokenize(text)
nuw=len(words)
uw=len(set(words))
print("%s contains %i nonunique and %i unique words"%(titlename,nuw,uw))
# Out:
# Mark Twain's Adventures of Huckleberry Finn contains 136751 nonunique and 8199 unique words

# %% [markdown]
# ### Extraction of Proper Nouns

# %%
p = inflect.engine()
d_tags = {}

docs_d={"Huckleberry Finn":text}
for key, value in docs_d.items():
    arr = []
    doc = nlp(value.replace('\n',''))
    #Keep these types of nlp entities
    keep_l = ['PERSON'] #,'NORP','PRODUCT','ORG']
    #Typo/model error + german corrections
    drop_t = []
    
    #Things inflect library handles poorly or to exclude from touching
    ex_ls = []
    
    for X in doc.ents:
        s1 = X.text
        if (X.label_ in keep_l) and (s1.lower() not in drop_t) and (s1):
            arr.append((s1, X.label_))
    d_tags[key] = arr
# pprint(d_tags)
names=[]
for k,v in d_tags.items():
    for vv in v:
        if vv[0] not in names:
            p=vv[0].replace("'","")
            p=p.title()
            names.append(p)
names=sorted(set(names))
print(len(names))
names
# Out:
# 572
# ['--Buck Harkness',
#  '--Obsequies Bein',
#  'A--_You',
#  'A-A-Men',
#  'A-Rab',
#  'A-Rabs',
#  'Ab Turner',
#  'Ablitionist',
#  'Abner Moore',
#  'Abner Shackleford',
#  'Abram Foster',
#  'Abram G. Foster',
#  'Adam',
#  'Afeard',
#  'Andy',
#  'Antonette',
#  'Archibald Nichols',
#  'Armand De Montalban',
#  'Aroun',
#  'Arter Breakfas',
#  'Ash',
#  'Aunt',
#  'Aunt Polly',
#  'Aunt Sally',
#  'Aunt Sallys',
#  'Awluz',
#  'Awluz Jis',
#  'Awready',
#  'Babtis',
#  'Baker',
#  'Baldy Shepherdson',
#  'Balum Inves De',
#  'Bang',
#  'Bartley',
#  'Baths_--That',
#  'Beeswax',
#  'Befo',
#  'Bekase',
#  'Ben',
#  'Ben A-Gwyne',
#  'Ben A-Running',
#  'Ben Afeard',
#  'Ben Afeard O',
#  'Ben Rogers',
#  'Ben Rucker',
#  'Ben Sich Punkin',
#  'Ben Thompson',
#  'Benvenuto Chelleeny',
#  'Bessie Thatcher',
#  'Betsy',
#  'Bilge',
#  'Bilgewater',
#  'Bill',
#  'Bill Whipple',
#  'Bill”\r\r\r\r',
#  'Blackguarding Sherburn',
#  'Blithesome',
#  'Blodgett',
# ...

# %%
rem=[]
for p in names:
    if "_" in p:
        rem.append(p)
    if "--" in p:
        rem.append(p)
    if p not in text:
        rem.append(p)
names=[p for p in names if p not in rem]
pp=[q for q in itertools.product(names,names) if q[0]!=q[1]]
for q in pp:
    if q[0] in q[1]:
        rem.append(q[0])
    if q[1] in q[0]:
        rem.append(q[1])
    w=q[0]+" "+q[1]
    if w in text:
        names.append(w)
        rem.append(q[0])
        rem.append(q[1])
names=[p for p in names if p not in rem]
names=sorted(set(names))
print(len(names))
names
# Out:
# 237
# ['A-A-Men',
#  'Ab Turner',
#  'Abner Moore',
#  'Abner Shackleford',
#  'Abram Foster',
#  'Abram G. Foster',
#  'Adam',
#  'Andy',
#  'Antonette',
#  'Archibald Nichols',
#  'Aroun',
#  'Ash',
#  'Aunt Polly',
#  'Aunt Sally',
#  'Babtis',
#  'Baldy Shepherdson',
#  'Bang',
#  'Bartley',
#  'Befo',
#  'Bekase',
#  'Ben Rogers',
#  'Ben Rucker',
#  'Ben Thompson',
#  'Benvenuto Chelleeny',
#  'Bessie Thatcher',
#  'Betsy',
#  'Bilgewater',
#  'Bill Whipple',
#  'Blodgett',
#  'Bob',
#  'Boggs',
#  'Brer Hightower',
#  'Brer Penrod',
#  'Brer Phelps',
#  'Buck Harkness',
#  'Bud',
#  'Bulrushers',
#  'Burton',
#  'Cain',
#  'Casanova',
#  'Charlemagne',
#  'Charles Second',
#  'Charlotte',
#  'Chaw',
#  'Cler',
#  'Clumbus',
#  'Collins',
#  'Conscience',
#  'Dad',
#  'Dah',
#  'Dar',
#  'Dat Jack',
#  'David Garrick',
#  'De Lo',
#  'Dear',
#  'Deef',
#  'Den',
#  'Dey',
#  'Dick',
#  'Didn',
#  'Dis',
#  'Doan',
#  'Douglas',
#  'Duke',
#  'Dunsinane',
#  'Edmund Kean',
# ...

# %%
rem=['A-A-Men', 'Aroun', 'Ash', 'Bang', 'Bekase', 'Chaw', 'Cler', 'Conscience', 'Dad', 'Dah', 'Dar', 'De Lo', 'Den', 'Dey', 'Didn', 'Dis', 'Doan', 'Ef', 'Gang', 'Geewhillikins', 'Huck De', 'Huck Lo', 'Huck Pa', 'Hunt', 'I.  ', 'I. Huck', 'I. Layin', 'I. No', 'I. Sherburn', 'I. Tom', 'I. Tom Sawyer', 'Jack Rob', 'Jane De', 'Jawin', 'Jis', 'Kill', 'Lawsy', 'Liberality', 'Maim', 'Mam', 'Mars Buck', 'Mars Jawge', 'Mars Sid?', 'Mars Tom Sawyer', 'Mary Jane De', 'Mort', 'Nuffn', 'Obsequies', 'Pap', 'Preachin', 'Roun', 'Rouse', 'Royal Rob', 'Said', 'Sarah Ma', 'Sarah William', 'Seegars', 'Seein', 'Sich', 'Snatch', 'Tame', 'Ther', 'Tom I', 'Tom Sawyer Waits', 'Tom Sawyers', 'Tryin', 'Whar', 'Wher', 'Work', 'Ye', 'Yit']
names=[p for p in names if p not in rem]
names=names+['Injun Joe', 'Tom Sawyer']
names=sorted(set(names))
print(len(names))
names
# Out:
# 169
# ['Ab Turner',
#  'Abner Moore',
#  'Abner Shackleford',
#  'Abram Foster',
#  'Abram G. Foster',
#  'Adam',
#  'Andy',
#  'Antonette',
#  'Archibald Nichols',
#  'Aroun',
#  'Aunt Polly',
#  'Aunt Sally',
#  'Babtis',
#  'Baldy Shepherdson',
#  'Bartley',
#  'Befo',
#  'Ben Rogers',
#  'Ben Rucker',
#  'Ben Thompson',
#  'Benvenuto Chelleeny',
#  'Bessie Thatcher',
#  'Betsy',
#  'Bilgewater',
#  'Bill Whipple',
#  'Blodgett',
#  'Bob',
#  'Boggs',
#  'Brer Hightower',
#  'Brer Penrod',
#  'Brer Phelps',
#  'Buck Harkness',
#  'Bud',
#  'Bulrushers',
#  'Burton',
#  'Cain',
#  'Casanova',
#  'Charlemagne',
#  'Charles Second',
#  'Charlotte',
#  'Clumbus',
#  'Collins',
#  'Dat Jack',
#  'David Garrick',
#  'Dear',
#  'Deef',
#  'Dick',
#  'Douglas',
#  'Duke',
#  'Dunsinane',
#  'Edmund Kean',
#  'Edward',
#  'Emmeline Grangerford',
#  'England',
#  'Fair Rosamun',
#  'Fretta',
#  'George Jack',
#  'George Jackson',
#  'George Peter',
#  'George Peters',
#  'Gilford Dudley',
# ...

# %%
nfreq=[]
for i in names: 
    nfreq.append(text.count(i))
pnf_df = pd.DataFrame(
    {'Names': names, 
     'Frequency of Occurrences': nfreq
    })
pnf_df=pnf_df[['Names','Frequency of Occurrences']]
pnf_df=pnf_df.sort_values(by ='Frequency of Occurrences',ascending=False)
# trf_df=trf_df[trf_df["Frequency of Occurrences"]>10]
print(len(pnf_df))
pnf_df[:50]
# Out:
# 169
#                     Names  Frequency of Occurrences
# 155            Tom Sawyer                        47
# 11             Aunt Sally                        40
# 164                Watson                        28
# 159           Uncle Silas                        19
# 26                  Boggs                        16
# 52                England                        15
# 78              Huck Finn                        13
# 10             Aunt Polly                        11
# 22             Bilgewater                        10
# 150                 Susan                        10
# 99                 Juliet                        10
# 25                    Bob                        10
# 47                   Duke                        10
# 151             Testament                         8
# 147                Sophia                         8
# 77                 Hooker                         8
# 16             Ben Rogers                         8
# ...

# %%
pnf_df.to_csv('Names_freqs.csv')

# %%
print("Run in %.2f seconds (%.2f minutes)" %(time.time() - start_time,(time.time() - start_time)/60))
# Out:
# Run in 71.66 seconds (1.19 minutes)
